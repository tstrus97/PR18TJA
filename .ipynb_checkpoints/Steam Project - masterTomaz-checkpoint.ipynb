# %% [markdown]
# Sodelujoči
#
#     Tomaž Štrus
#     Anže Košir
#     Jan Harej
#
# O projektu: Iz platforme Steam, namenjenu predvsem za distrubicijo video iger, bomo zbrali podatke igrah več ljudi, ter analizirali stvari kot so npr. koliko iger, ki jih kupijo dejansko preigrajo, kolika časa bo nekdo zapravil za neko igro, kakšno igro bo kupil naslednjo, glede na svoje igre ipd.
#
# Podatki: Uporabili bomo API, ki ga ponuja Steam: https://developer.valvesoftware.com/wiki/Steam_Web_API#JSON Tu lahko dobimo podatko o čisto vsemu kar potrebujemo npr. o uporabniku, njegove igre, prijatelji, koliko ur je igral neko igro, ... Dobili bomo podatke za npr. 100.000+ uporabnikov (prijatelji naših prijateljev, in njihov prijateljev itd.)

# %% [markdown]
# ## Vprašanja za raziskavo
# 1. Povprečno dokončanje igre
# 2. Število in vrsta Bannov v povezavi z javnimi/privatnimi profili
# 3. Najmanjkrat odklenjeni dosežki za igrane igre
# 4. Število prijateljev glede na "starost" računa

# %%
from scripts.imports import *
from scripts.data_variables import *
from scripts.gameStats_functions import *

# %%
from scripts.get_read_write import *

# %%
data = read_all_from_file()
player_ids = data[0] 
player_summaries = data[1]
player_friends = data[2]
player_games = data[3]
player_achievements = data[4]
player_bans = data[5]
global_game_stats = data[6]
game_names= data[7]
#player_ids = read_player_ids()
print("Current database size: {} users".format(len(player_ids)))
#player_summaries = read_player_summaries()
#player_friends = read_player_friends()
#player_games = read_player_games()
#player_bans = read_player_bans()
# Out:
# INFO: reading ids
# INFO: reading ids finished
# INFO: reading summaries
# INFO: reading summaries finished
# INFO: reading friends
# INFO: reading friends finished
# INFO: reading games
# INFO: reading games finished
# INFO: reading achievements
# INFO: reading achievements finished
# INFO: reading bans
# INFO: reading bans finished
# INFO: reading global game stats
# INFO: reading global game stats finished
# INFO: reading game names
# INFO: reading game names finished
# Current database size: 100 users

# %%
player_summaries
# Out:
# {'76561198049844706': {'steamid': '76561198049844706',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Koala BOT',
#   'lastlogoff': 1527181073,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198049844706/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fb/fb07fca5a2889ef24bc1d57a6835220335887efb.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fb/fb07fca5a2889ef24bc1d57a6835220335887efb_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fb/fb07fca5a2889ef24bc1d57a6835220335887efb_full.jpg',
#   'personastate': 3,
#   'primaryclanid': '103582791437805031',
#   'timecreated': 1317497364,
#   'personastateflags': 0,
#   'loccountrycode': 'SI'},
#  '76561198347576152': {'steamid': '76561198347576152',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Gabriiell',
#   'lastlogoff': 1527190038,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198347576152/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_full.jpg',
#   'personastate': 1,
#   'primaryclanid': '103582791429521408',
#   'timecreated': 1480274516,
#   'personastateflags': 0},
#  '76561197960531524': {'steamid': '76561197960531524',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Riso',
#   'lastlogoff': 1527187412,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/id/baise-moi/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/61/61e6d091a82b9e71e11833d59bdf1316a42601fe.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/61/61e6d091a82b9e71e11833d59bdf1316a42601fe_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/61/61e6d091a82b9e71e11833d59bdf1316a42601fe_full.jpg',
#   'personastate': 0,
#   'realname': 'Riso',
#   'primaryclanid': '103582791438953305',
#   'timecreated': 1063484400,
#   'personastateflags': 0,
#   'loccountrycode': 'AT'},
#  '76561198197467622': {'steamid': '76561198197467622',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Boo ^_^',
#   'lastlogoff': 1502717814,
#   'profileurl': 'https://steamcommunity.com/id/_the_queen_/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars
medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/a3/a3b74debc61572df4637692eefea6fe63fdf6f97_full.jpg',
#   'personastate': 0,
#   'realname': 'Joe',
#   'primaryclanid': '103582791455567137',
#   'timecreated': 1422039872,
#   'personastateflags': 0,
#   'loccountrycode': 'SI',
#   'locstatecode': '61'},
#  '76561197978795974': {'steamid': '76561197978795974',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Reaper',
#   'lastlogoff': 1526080532,
#   'commentpermission': 2,
#   'profileurl': 'https://steamcommunity.com/profiles/76561197978795974/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/c2/c22650f7c3364726a1ce458b0b78a6b468ad3e65.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/c2/c22650f7c3364726a1ce458b0b78a6b468ad3e65_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/c2/c22650f7c3364726a1ce458b0b78a6b468ad3e65_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791431214421',
#   'timecreated': 1130001281,
#   'personastateflags': 0,
#   'loccountrycode': 'AT',
#   'locstatecode': '03'},
#  '76561197971107992': {'steamid': '76561197971107992',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'sfpsnakeplissken',
#   'lastlogoff': 1527190292,
#   'commentpermission': 2,
#   'profileurl': 'https://steamcommunity.com/id/ffsnakeplissken/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/ef/ef82de1a15cc43737b36074683ee20309878c6c7.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/ef/ef82de1a15cc43737b36074683ee20309878c6c7_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/ef/ef82de1a15cc43737b36074683ee20309878c6c7_full.jpg',
#   'personastate': 0,
#   'realname': 'Snatch Snatcho',
#   'primaryclanid': '103582791456602800',
#   'timecreated': 1101403922,
#   'personastateflags': 0},
#  '76561198013007796': {'steamid': '76561198013007796',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'tchervychek.',
#   'lastlogoff': 1527151872,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/id/tchervychek/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/15/15821591b4621536debdf2d29f242f4acb20e04e.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/15/15821591b4621536debdf2d29f242f4acb20e04e_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/15/15821591b4621536debdf2d29f242f4acb20e04e_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791434868677',
#   'timecreated': 1250855595,
#   'personastateflags': 0,
#   'loccountrycode': 'SI',
#   'locstatecode': '71'},
#  '76561198260799914': {'steamid': '76561198260799914',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'michael Scolfield',
#   'lastlogoff': 1501183467,
#   'profileurl': 'https://steamcommunity.com/id/TyreeseWilliams/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/94/944a87eb61f6ed69ab67655d1fb53cb77d76fc4b.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/94/944a87eb61f6ed69ab67655d1fb53cb77d76fc4b_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/94/944a87eb61f6ed69ab67655d1fb53cb77d76fc4b_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791429521408',
#   'timecreated': 1447701293,
#   'personastateflags': 0},
#  '76561198075264723': {'steamid': '76561198075264723',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'ArrowsK',
#   'lastlogoff': 1527173214,
#   'profileurl': 'https://steamcommunity.com/id/lorol/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/4f/4fc21028b29d67e3615b5cbada72ff45be9924da.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/4f/4fc21028b29d67e3615b5cbada72ff45be9924da_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/4f/4fc21028b29d67e3615b5cbada72ff45be9924da_full.jpg',
#   'personastate': 0,
#   'realname': 'Laurent Resman',
#   'primaryclanid': '103582791439674615',
#   'timecreated': 1352388035,
#   'personastateflags': 0,
#   'loccountrycode': 'SI'},
#  '76561198200202646': {'steamid': '76561198200202646',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'GhostLady',
#   'lastlogoff': 1527179949,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/id/Grabec/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/7c/7cc3c69d827ca06d58899f68e46ea0397e0b9798.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/7c/7cc3c69d827ca06d58899f68e46ea0397e0b9798_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/7c/7cc3c69d827ca06d58899f68e46ea0397e0b9798_full.jpg',
#   'personastate': 3,
#   'realname': 'Gal',
#   'primaryclanid': '103582791460345371',
#   'timecreated': 1433596502,
#   'personastateflags': 0},
#  '76561198201938789': {'steamid': '76561198201938789',
#   'communityvisibilitystate': 1,
#   'profilestate': 1,
#   'personaname': '--D3K1--',
#   'lastlogoff': 1517072915,
#   'profileurl': 'https://steamcommunity.com/id/1651998/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/54
#   'primaryclanid': '103582791429521408',
#   'timecreated': 1365688035,
#   'personastateflags': 0,
#   'gameextrainfo': 'DiRT 3 Complete Edition',
#   'gameid': '321040',
#   'loccountrycode': 'SI'},
#  '76561197970359001': {'steamid': '76561197970359001',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': '[CPC] cooly08',
#   'lastlogoff': 1527115742,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/id/cooly08/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/40/404e868a62fa9d3943ee14321ab927fe6939fb29.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/40/404e868a62fa9d3943ee14321ab927fe6939fb29_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/40/404e868a62fa9d3943ee14321ab927fe6939fb29_full.jpg',
#   'personastate': 3,
#   'realname': 'Denis',
#   'primaryclanid': '103582791438138708',
#   'timecreated': 1100605874,
#   'personastateflags': 0,
#   'loccountrycode': 'FR',
#   'locstatecode': 'C1',
#   'loccityid': 16327},
#  '76561198050752491': {'steamid': '76561198050752491',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': '♤ JokerMan ♤',
#   'lastlogoff': 1526984546,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/id/Joker_Man/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/12/128f92dac58e2669e8be2f8b7c66c93ff4c1696e.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/12/128f92dac58e2669e8be2f8b7c66c93ff4c1696e_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/12/128f92dac58e2669e8be2f8b7c66c93ff4c1696e_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791457049097',
#   'timecreated': 1318965771,
#   'personastateflags': 0,
#   'loccountrycode': 'SI'},
#  '76561198084658048': {'steamid': '76561198084658048',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'lucky#2',
#   'lastlogoff': 1516913618,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198084658048/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/44/440d42ef6657c6463e64e89ccdd26816ffa17f20.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/44/440d42ef6657c6463e64e89ccdd26816ffa17f20_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/44/440d42ef6657c6463e64e89ccdd26816ffa17f20_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791432987389',
#   'timecreated': 1361612943,
#   'personastateflags': 0},
#  '76561198255557412': {'steamid': '76561198255557412',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Piratk3 Gamdom.com',
#   'lastlogoff': 1524672469,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198255557412/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/c0/c02f54408f79d5688e04332af794a6bcf978e48e.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/c0/c02f54408f79d5688e04332af794a6bcf978e48e_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/c0/c02f54408f79d5688e04332af794a6bcf978e48e_full.jpg',
#   'personastate': 0,
#   'realname': 'Ziga B.',
#   'primaryclanid': '103582791455533294',
#   'timecreated': 1445013646,
#   'personastateflags': 0,
#   'loccountrycode': 'SI',
#   'locstatecode': '61'},
#  '76561198311055357': {'steamid': '76561198311055357',
#   'communityvisibilitystate': 3,
#   'personaname': 'Nursum-7',
#   'profileurl': 'https://steamcommunity.com/profiles/76561198311055357/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791429521408',
#   'timecreated': 1465887509,
#   'personastateflags': 0},
#  '76561198012850892': {'steamid': '76561198012850892',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'VenomBlades',
#   'lastlogoff': 1527116730,
#   'profileurl': 'https://steamcommunity.com/id/VenomBlades/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/55/55e86a3f351cf10eefc1699352607f2140fc26ea.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/55/55e86a3f351cf10eefc1699352607f2140fc26ea_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/55/55e86a3f351cf10eefc1699352607f2140fc26ea_full.jpg',
#   'personastate': 3,
#   'primaryclanid': '103582791432579087',
#   'timecreated': 1250363859,
#   'personastateflags': 0,
#   'gameextrainfo': 'DARK SOULS™: REMASTERED',
#   'gameid': '570940',
#   'loccountrycode': 'SI'},
#  '76561198064053593': {'steamid': '76561198064053593',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Zakhrayshek',
#   'lastlogoff': 1527112606,
#   'profileurl': 'https://steamcommunity.com/id/Zakhrayshek/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/06/06bba48d6f423281f02ef3592d3f55efc5442f3c.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/06/06bba48d6f423281f02ef3592d3f55efc5442f3c_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars
medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/b0/b0302d2545e545c7fa4595eaccdb318a469e0350_full.jpg',
#   'personastate': 0,
#   'realname': 'John',
#   'primaryclanid': '103582791435206636',
#   'timecreated': 1360071115,
#   'personastateflags': 0,
#   'loccountrycode': 'US'},
#  '76561198234735696': {'steamid': '76561198234735696',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'galpatrik123',
#   'lastlogoff': 1526931015,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198234735696/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791429521408',
#   'timecreated': 1434812461,
#   'personastateflags': 0},
#  '76561198166276362': {'steamid': '76561198166276362',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'din0v',
#   'lastlogoff': 1480454696,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/id/vilijam123/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/1f/1f359dee0e34e4188782f8da6a25f9881297c76f.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/1f/1f359dee0e34e4188782f8da6a25f9881297c76f_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/1f/1f359dee0e34e4188782f8da6a25f9881297c76f_full.jpg',
#   'personastate': 0,
#   'realname': 'Vilijam',
#   'primaryclanid': '103582791433268289',
#   'timecreated': 1417644941,
#   'personastateflags': 0,
#   'loccountrycode': 'MK'},
#  '76561198068119323': {'steamid': '76561198068119323',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'dany2945',
#   'lastlogoff': 1527164826,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/id/dany2945/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/41/41cc6c53a01a62342bbf3d414bcedc77b88459e8.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/41/41cc6c53a01a62342bbf3d414bcedc77b88459e8_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/41/41cc6c53a01a62342bbf3d414bcedc77b88459e8_full.jpg',
#   'personastate': 1,
#   'realname': 'Daniel',
#   'primaryclanid': '103582791434672565',
#   'timecreated': 1343409413,
#   'personastateflags': 0,
#   'loccountrycode': 'RO'},
#  '76561198155836946': {'steamid': '76561198155836946',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Ric0la',
#   'lastlogoff': 1526665349,
#   'profileurl': 'https://steamcommunity.com/id/RainbowVodkaRU/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/12/12feeb18ef1e43f00ad91e31562246c2720dfb80.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/12/12feeb18ef1e43f00ad91e31562246c2720dfb80_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/12/12feeb18ef1e43f00ad91e31562246c2720dfb80_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791429521408',
#   'timecreated': 1411499852,
#   'personastateflags': 0},
#  '76561197971198233': {'steamid': '76561197971198233',
#   'communityvisibilitystate': 1,
#   'profilestate': 1,
#   'personaname': 'Armandiux',
#   'lastlogoff': 1526863854,
#   'profileurl': 'https://steamcommunity.com/id/armandiux/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/e4/e435df782e4937ecf5cf61c4c5d9b4a75607a54e.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/e4/e435df782e4937ecf5cf61c4c5d9b4a75607a54e_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/e4/e435df782e4937ecf5cf61c4c5d9b4a75607a54e_full.jpg',
#   'personastate': 0},
#  '76561197970350739': {'steamid': '76561197970350739',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Five',
#   'lastlogoff': 1524746450,
#   'profileurl': 'https://steamcommunity.com/id/Five_Ahn/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/c0/c06420a76c580c83d6004d3e5958d86f6c7e867c.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/c0/c06420a76c580c83d6004d3e5958d86f6c7e867c_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/c0/c06420a76c580c83d6004d3e5958d86f6c7e867c_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791429557049',
#   'timecreated': 1100599146,
#   'personastateflags': 0,
#   'loccountrycode': 'SE'},
#  '76561198046995056': {'steamid': '76561198046995056',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Killerschnitzel',
#   'lastlogoff': 1527113411,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198046995056/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/64/6485d8022cd8b8dc5adfbe533ca02f832b088e1d.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/64/6485d8022cd8b8dc5adfbe533ca02f832b088e1d_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/64/6485d8022cd8b8dc5adfbe533ca02f832b088e1d_full.jpg',
#   'personastate': 1,
#   'realname': 'Thore',
#   'primaryclanid': '103582791455751544',
#   'timecreated': 1313507932,
#   'personastateflags': 0,
# ...
#   'profileurl': 'https://steamcommunity.com/profiles/76561198094341403/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/2b/2b3275cd77d827b78f1eda52f81547c68212be73.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/2b/2b3275cd77d827b78f1eda52f81547c68212be73_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/2b/2b3275cd77d827b78f1eda52f81547c68212be73_full.jpg',
#   'personastate': 0,
#   'realname': 'Dominic',
#   'primaryclanid': '103582791434581435',
#   'timecreated': 1371123610,
#   'personastateflags': 0,
#   'loccountrycode': 'PR'},
#  '76561198245677000': {'steamid': '76561198245677000',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'crazythegreat',
#   'lastlogoff': 1527103654,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198245677000/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/a2/a2025c2886c1045daa15234d0a055686c7958cb9.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/a2/a2025c2886c1045daa15234d0a055686c7958cb9_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/a2/a2025c2886c1045daa15234d0a055686c7958cb9_full.jpg',
#   'personastate': 1,
#   'realname': 'aljaz',
#   'primaryclanid': '103582791439759404',
#   'timecreated': 1440071962,
#   'personastateflags': 0,
#   'loccountrycode': 'US',
#   'locstatecode': 'NV',
#   'loccityid': 2374},
#  '76561198343199692': {'steamid': '76561198343199692',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'csgofast.com 7 csgoloto.com',
#   'lastlogoff': 1527185582,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198343199692/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/54/5448dd84ecf6e2f2b02ddcefe6ef093d4fe4a542.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/54/5448dd84ecf6e2f2b02ddcefe6ef093d4fe4a542_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/54/5448dd84ecf6e2f2b02ddcefe6ef093d4fe4a542_full.jpg',
#   'personastate': 1,
#   'primaryclanid': '103582791457605895',
#   'timecreated': 1478954361,
#   'personastateflags': 0,
#   'loccountrycode': 'SI'},
#  '76561197978102369': {'steamid': '76561197978102369',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'kaasu::',
#   'lastlogoff': 1527109698,
#   'commentpermission': 2,
#   'profileurl': 'https://steamcommunity.com/id/kaasungen/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/5a/5aeab2bb1051eab884e85927e55438b8ecfabd04.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/5a/5aeab2bb1051eab884e85927e55438b8ecfabd04_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/5a/5aeab2bb1051eab884e85927e55438b8ecfabd04_full.jpg',
#   'personastate': 1,
#   'primaryclanid': '103582791430560627',
#   'timecreated': 1126881558,
#   'personastateflags': 0},
#  '76561198131512770': {'steamid': '76561198131512770',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'KiWii',
#   'lastlogoff': 1396201245,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198131512770/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_full.jpg',
#   'personastate': 0,
#   'realname': 'Aleks',
#   'primaryclanid': '103582791429521408',
#   'timecreated': 1396200662,
#   'personastateflags': 0,
#   'loccountrycode': 'SI'},
#  '76561198114859238': {'steamid': '76561198114859238',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'michel.kovach',
#   'lastlogoff': 1527169659,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198114859238/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791429521408',
#   'timecreated': 1384607126,
#   'personastateflags': 0},
#  '76561198067043154': {'steamid': '76561198067043154',
#   'communityvisibilitystate': 1,
#   'profilestate': 1,
#   'personaname': 'bloody9',
#   'lastlogoff': 1527074587,
#   'commentpermission': 2,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198067043154/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/82/82bfb68f7a35005711a01751faea262b1ac7f26a.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/82/82bfb68f7a35005711a01751faea262b1ac7f26a_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/82/82bfb68f7a35005711a01751faea262b1ac7f26a_full.jpg',
#   'personastate': 0},
#  '76561198043441963': {'steamid': '76561198043441963',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'ThatCreepyGuy',
#   'lastlogoff': 1527159927,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/id/FG14/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/c1/c1bcef63f8ac0e698eeaced4a55c0609c0587a1e.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/c1/c1bcef63f8ac0e698eeaced4a55c0609c0587a1e_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/c1/c1bcef63f8ac0e698eeaced4a55c0609c0587a1e_full.jpg',
#   'personastate': 3,
#   'realname': 'Admir',
#   'primaryclanid': '103582791434215417',
#   'timecreated': 1308373789,
#   'personastateflags': 0,
#   'loccountrycode': 'SI'},
#  '76561197983528456': {'steamid': '76561197983528456',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'whiteFOX.MistaX32 [YA]',
#   'lastlogoff': 1523979198,
#   'profileurl': 'https://steamcommunity.com/profiles/76561197983528456/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/0b/0b6a226fb5470a32a85260fbb2e91ffd4445b9b0.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/0b/0b6a226fb5470a32a85260fbb2e91ffd4445b9b0_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/0b/0b6a226fb5470a32a85260fbb2e91ffd4445b9b0_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791457108800',
#   'timecreated': 1151952214,
#   'personastateflags': 0,
#   'loccountrycode': 'BE'},
#  '76561198046980777': {'steamid': '76561198046980777',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Non5ens3',
#   'lastlogoff': 1527189090,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198046980777/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/1f/1fcb0c81d5e47e2d65ba466a6d92d3c9f2b2b655.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/1f/1fcb0c81d5e47e2d65ba466a6d92d3c9f2b2b655_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/1f/1fcb0c81d5e47e2d65ba466a6d92d3c9f2b2b655_full.jpg',
#   'personastate': 0,
#   'realname': 'Matej Basa',
#   'primaryclanid': '103582791459740959',
#   'timecreated': 1313516501,
#   'personastateflags': 0,
#   'loccountrycode': 'SI',
#   'locstatecode': '39'},
#  '76561198096007517': {'steamid': '76561198096007517',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'OBELIXXX',
#   'lastlogoff': 1525207905,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198096007517/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/ed/ed56706aeb6f34f0cbae2ad6cfc195f7226a31e5.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/ed/ed56706aeb6f34f0cbae2ad6cfc195f7226a31e5_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/ed/ed56706aeb6f34f0cbae2ad6cfc195f7226a31e5_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791455567137',
#   'timecreated': 1372538236,
#   'personastateflags': 0},
#  '76561198009469751': {'steamid': '76561198009469751',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'float',
#   'lastlogoff': 1527172542,
#   'profileurl': 'https://steamcommunity.com/id/yugic/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/ce/ce4c9579872f8ba3f9d6fb0d89bc9d43f53651e6.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/ce/ce4c9579872f8ba3f9d6fb0d89bc9d43f53651e6_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/ce/ce4c9579872f8ba3f9d6fb0d89bc9d43f53651e6_full.jpg',
#   'personastate': 0,
#   'realname': 'aJuvan',
#   'primaryclanid': '103582791434140264',
#   'timecreated': 1241025165,
#   'personastateflags': 0,
#   'loccountrycode': 'SI',
#   'locstatecode': '61'},
#  '76561198033366594': {'steamid': '76561198033366594',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'jerry',
#   'lastlogoff': 1525700805,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198033366594/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791429524891',
#   'timecreated': 1289501580,
#   'personastateflags': 0},
#  '76561197970893987': {'steamid': '76561197970893987',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'ShopSuey',
#   'lastlogoff': 1527148968,
#   'profileurl': 'https://steamcommunity.com/profiles/76561197970893987/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791429521408',
#   'timecreated': 1100975273,
#   'personastateflags': 0},
#  '76561198132033248': {'steamid': '76561198132033248',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Smoky',
#   'lastlogoff': 1527097880,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198132033248/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/4a/4a3e0f49dc177b322305551e9b09621aaebe1543.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/4a/4a3e0f49dc177b322305551e9b09621aaebe1543_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/4a/4a3e0f49dc177b322305551e9b09621aaebe1543_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791429521408',
#   'timecreated': 1396623966,
#   'personastateflags': 0,
#   'loccountrycode': 'SI'},
#  '76561198802773182': {'steamid': '76561198802773182',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'TammyShinigami',
#   'lastlogoff': 1526970638,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198802773182/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/d7/d7b05e40c034f8ffef646f4221dbfa971dd12bb5.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/d7/d7b05e40c034f8ffef646f4221dbfa971dd12bb5_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/d7/d7b05e40c034f8ffef646f4221dbfa971dd12bb5_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791429521408',
#   'timecreated': 1515109181,
#   'personastateflags': 0},
#  '76561198079711430': {'steamid': '76561198079711430',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Bullken',
#   'lastlogoff': 1398911190,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198079711430/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/b5/b5410939107e8e50f93fb9af8287d8d24cdff24f.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/b5/b5410939107e8e50f93fb9af8287d8d24cdff24f_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/b5/b5410939107e8e50f93fb9af8287d8d24cdff24f_full.jpg',
#   'personastate': 0,
#   'realname': 'marc',
#   'primaryclanid': '103582791434100853',
#   'timecreated': 1356614564,
#   'personastateflags': 0,
#   'loccountrycode': 'DE',
#   'locstatecode': '14'},
#  '76561198174645730': {'steamid': '76561198174645730',
#   'communityvisibilitystate': 3,
#   'personaname': 'glasbeni.gams',
#   'lastlogoff': 1461781410,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198174645730/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791429521408',
#   'timecreated': 1421604980,
#   'personastateflags': 0},
#  '76561198301768254': {'steamid': '76561198301768254',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'kosir.jostek',
#   'lastlogoff': 1525466308,
#   'profileurl': 'https://steamcommunity.com/profiles/76561198301768254/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fe/fef49e7fa7e1997310d705b2a6158ff8dc1cdfeb_full.jpg',
#   'personastate': 0,
#   'primaryclanid': '103582791455492378',
#   'timecreated': 1462195691,
#   'personastateflags': 0},
#  '76561198047413492': {'steamid': '76561198047413492',
#   'communityvisibilitystate': 3,
#   'profilestate': 1,
#   'personaname': 'Le Sexxy Bishop',
#   'lastlogoff': 1526983207,
#   'commentpermission': 1,
#   'profileurl': 'https://steamcommunity.com/id/lordomega97/',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/ee/eec1e8b81d2ef7c3105b19a43fe860f08635d0de.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/ee/eec1e8b81d2ef7c3105b19a43fe860f08635d0de_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/ee/eec1e8b81d2ef7c3105b19a43fe860f08635d0de_full.jpg',
#   'personastate': 0,
#   'realname': 'Skofy Mofy',
#   'primaryclanid': '103582791434515796',
#   'timecreated': 1314043897,
#   'personastateflags': 0,
#   'loccountrycode': 'VA'}}

# %% [markdown]
# # Odgovori na vprašanja

# %% [markdown]
# Najbolj igrane igre

# %%
def getMostCommonGamesAndHighestPlaytimeSorted( player_games):
    globalGamePlayTime=dict()
    numberOfPlayersForGame=dict()
    for user in player_games:
        if(player_games[user]!={} and player_games[user]['game_count']!=0):
            for game_info in player_games[user]["games"]:
                if( game_info['appid'] not in globalGamePlayTime):
                    globalGamePlayTime[game_info['appid']]=game_info['playtime_forever']
                    numberOfPlayersForGame[game_info['appid']]=1
                else:
                    globalGamePlayTime[game_info['appid']]+=game_info['playtime_forever']
                    numberOfPlayersForGame[game_info['appid']]+=1
    TopTotalPlaytime= sorted(globalGamePlayTime.items(), key=lambda x: x[1], reverse=True)
    TopBoughtGames= sorted(numberOfPlayersForGame.items(), key=lambda x: x[1], reverse=True)
    return (TopBoughtGames,TopTotalPlaytime)


def plotTopPlaytimeGames( sortedGames):
    games=[]
    playtimes=[]
    for game,playtime in sortedGames:
        games.append(str(game_names[str(game)]))
        playtimes.append(playtime/60)
    y_pos = np.arange(len(games))
    plt.figure(figsize=(15,15))
    plt.barh(games,playtimes, align='center', alpha=0.5)
    #plt.yticks(y_pos, games)
    plt.xlabel("Čas igranja v urah")
    plt.title('Največ igranih iger')
    plt.show()
    return None

def plotTopBoughtGames( sortedGames):
    games=[]
    playtimes=[]
    for game,playtime in sortedGames:
        games.append(str(game_names[str(game)]))
        playtimes.append(playtime)
    y_pos = np.arange(len(games))
    plt.figure(figsize=(15,15))
    plt.barh(games,playtimes, align='center', alpha=0.5)
    #plt.yticks(y_pos, games)
    plt.xlabel("Najbolj razširjena igra")
    plt.title('št. igralcev z to igro')
    plt.show()
    return None

# %%
(TopBoughtGames,TopTotalPlaytime)=getMostCommonGamesAndHighestPlaytimeSorted(player_games)
plotTopPlaytimeGames(TopTotalPlaytime[10:0:-1])
plotTopBoughtGames(TopBoughtGames[10:0:-1])

# %%
player_countries=dict()
for pid in player_summaries:
    if('loccountrycode' in player_summaries[pid]):
        if(player_summaries[pid]['loccountrycode'] not in player_countries):
            player_countries[player_summaries[pid]['loccountrycode']]=0
        player_countries[player_summaries[pid]['loccountrycode']]+=1
sortedPlayerCountries= sorted(player_countries.items(), key=lambda x: x[1], reverse=True)

def plotCountries( player_countries):
    number=[]
    countries=[]
    for country,persons in player_countries:
        countries.append(country)
        number.append(persons)
    y_pos = np.arange(len(countries))
    plt.figure(figsize=(15,15))
    plt.barh(countries,number, align='center', alpha=0.5)
    #plt.yticks(y_pos, games)
    plt.xlabel("Št igralcev")
    plt.title('Št. igralcev po državah')
    plt.show()
    return None

plotCountries(sortedPlayerCountries[::-1])

# %% [markdown]
# Kakšen je common prefix med imenom in usernamom

# %%
#Uporabili bomo jellyfish za funkcije merjenja razdalj med dvema stringoma
#!pip install jellyfish
import jellyfish
#jellyfish.levenshtein_distance(  s1,s2 )
#jellyfish.jaro_distance(s1,s2 )
#jellyfish.damerau_levenshtein_distance(s1,s2)

# %%
'''def commonprefix(m):
    "Given a list of pathnames, returns the longest common leading component"
    if not m: return ''
    s1 = min(m)
    s2 = max(m)
    for i, c in enumerate(s1):
        if c != s2[i]:
            return s1[:i]
    return s1
'''

playerNamesSimilarity=[]
sameNames8=[]
sameNames5=[]
for pid in player_summaries:
    if('personaname' in player_summaries[pid] and 'realname' in player_summaries[pid]):
        a=jellyfish.jaro_distance(player_summaries[pid]['personaname'],player_summaries[pid]['realname'])
        playerNamesSimilarity.append(a)
        if(a>0.8):
            sameNames8.append((player_summaries[pid]['personaname'],player_summaries[pid]['realname']))
        if(a<0.8 and a>0.5):
            sameNames5.append((player_summaries[pid]['personaname'],player_summaries[pid]['realname']))
plt.hist(playerNamesSimilarity)
print(sameNames)
# Out:
# [('Riso', 'Riso'), ('Chrissy', 'Chrissy'), ('Jodli', 'Jodli'), ('Thorvald', 'Thorvald ter Meer')]

# %% [markdown]
# ### 1. Povprečno dokončanje igre

# %% [markdown]
# ### 2. Število in vrsta Bannov v povezavi z javnimi/privatnimi profili

# %% [markdown]
# ### 3. Najmanjkrat odklenjeni dosežki za igrane igre

# %% [markdown]
# ### 4. Število prijateljev glede na "starost" računa

# %% [markdown]
# ### 5. Odvisnost med težavnostjo igre in njenim uspehom
